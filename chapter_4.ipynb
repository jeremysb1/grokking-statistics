# %% [markdown]
# <a href="https://colab.research.google.com/github/jeremysb1/grokking-statistics/blob/main/chapter_4.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# Normal Dsitribution

import numpy as np
import matplotlib.pyplot as plt
from scipy.stats import norm

mu, sigma = 64, 2.5

x = np.linspace(mu-sigma*4, mu+sigma*4, 1000)
y = norm.pdf(x, mu, sigma)

plt.plot(x,y)
plt.title("Height Distribution of U.S. Women")
plt.xlabel("Height (inches)")
plt.ylabel("Probability Density")
plt.grid(True, alpha=0.3)
plt.show()

# %%
import numpy as np
from numpy.random import normal
from scipy.stats import norm
import matplotlib.pyplot as plt

x = np.array([27, 22, 28, 27, 26, 28, 31, 25, 25, 33, 24, 28, 28, 30,
             26, 25, 29, 28, 30, 30, 22, 28, 36, 27, 26, 31, 30, 25,
             27, 32, 25, 23, 27, 24, 28, 24, 27, 28, 30, 26, 33, 29,
             31, 29, 27, 31, 20, 23, 25, 29, 30, 24, 29, 28, 25, 25,
             30, 30, 27, 36, 26, 31, 24, 29, 34, 27, 23, 29, 27, 19,
             28, 30, 26, 29, 27, 30, 29, 28])

plt.hist(x, bins=np.arange(min(x), max(x)+2) - 0.5, alpha=1.0, color='#002d8b')

plt.title('Perfect Amount of Coffee for 16oz Cup')
plt.xlabel('Weight (grams)')
plt.ylabel('Barista Votes')
plt.xticks(range(min(x), max(x) +1))
plt.show()

# %%
import numpy as np

x = np.array([27, 22, 28, 27, 26, 28, 31, 25, 25, 33, 24, 28, 28, 30,
              26, 25, 29, 28, 30, 30, 22, 28, 36, 27, 26, 31, 30, 25,
              27, 32, 25, 23, 27, 24, 28, 24, 27, 28, 30, 26, 33, 29,
              31, 29, 27, 31, 20, 23, 25, 29, 30, 24, 29, 28, 25, 25,
              30, 30, 27, 36, 26, 31, 24, 29, 34, 27, 23, 29, 27, 19,
              28, 30, 26, 29, 27, 30, 29, 28])

mean, median, std = np.mean(x), np.median(x), np.std(x, ddof=1)

print(f"MEAN: {mean: .1f}, MEDIAN: {median: .1f}, STD: {std: .1f}")
# Out:
# MEAN:  27.6, MEDIAN:  28.0, STD:  3.2

# %%
# Scaled down the y-axis so the bell curve has an area of 1.0

mu, sigma = x.mean(), x.std()

x_line = np.linspace(mu - sigma*4, mu + sigma*4, 1000)
y = norm.pdf(x_line, mu, sigma)
plt.plot(x_line, y)

plt.hist(x, bins=np.arange(min(x), max(x) + 2) - 0.5, alpha=.4, color='#002d8b', density=True)

plt.title("Ideal Coffee Grounds for 16oz Cup")
plt.xlabel("Weight (grams)")
plt.ylabel("Probability Density")
plt.grid(True, alpha=0.3)
plt.show()

# %%
# creating probability density function in python

from math import sqrt, exp, pi
import numpy as np
import matplotlib.pyplot as plt

def normal_pdf(x, mu, sigma):
    return 1/(sigma * sqrt(2*pi)) *exp(-((x-mu)/(2*sigma))**2)

mu, sigma = 27.6, 3.18
x_line = np.linspace(mu - sigma * 4, mu + sigma * 4, 1000)
y = [normal_pdf(x, mu, sigma) for x in x_line]
plt.plot(x_line, y)

plt.title("Ideal Coffee Grounds for 16oz Cup")
plt.xlabel("Weight (grams)")
plt.ylabel("Probability Density")
plt.grid(True, alpha=0.3)
plt.show()

# %%
# Calculating probabilities with the normal distribution

import numpy as np
import matplotlib.pyplot as plt
from scipy.stats import norm

mu, sigma = 64, 3
x = np.linspace(mu - sigma*4, mu + sigma*4, 1000)
y = norm.pdf(x, mu, sigma)

lower, upper = 61, 63

plt.plot(x, y)

shade_x = x[(x >= lower) & (x <= upper)]
shade_y = norm.pdf(shade_x, mu, sigma)
plt.fill_between(shade_x, shade_y, alpha=0.5, color='#002d8b')

plt.title("Weight Distribution of Golden Retrievers")
plt.xlabel("Weight (lbs)")
plt.ylabel("Probability Density")
plt.grid(True, alpha=0.3)
plt.show()

# %%
from scipy.stats import norm

mu, sigma = 64, 3
area = norm.cdf(63, mu, sigma)
print(f"Area Under Curve: {area: .4f}")
# Out:
# Area Under Curve:  0.3694

# %%
area = norm.cdf(63, mu, sigma) - norm.cdf(61, mu, sigma)
print("Area between 61 and 63: {area:.4f}")
# Out:
# Area between 61 and 63: {area:.4f}

# %%
# Chebyshev's Theorem

mu, sigma = 7, 1.5

k = 3.0
p_min = 1.0 - (1.0/k**2)
lower, upper = mu-3*sigma, mu+3*sigma

print(f"At least {p_min*100:.1f}% of chips last between {lower:.1f} and {upper:.1f} years.")
# Out:
# At least 88.9% of chips last between 2.5 and 11.5 years.
